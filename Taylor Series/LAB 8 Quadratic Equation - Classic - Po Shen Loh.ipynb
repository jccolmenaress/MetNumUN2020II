# %% [markdown]
# #1. Plot the following functions in a x range that include that include the vertex and the roots (if there are roots)

# %% [markdown]
# #$x^{2}$

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

def f(z):
    return z ** 2

def df(z):
    return 2 * z

def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = 0

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display1(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(x)=Z^2')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=x^2')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# #$(x-1)^{2} = x^{2}-2x+1$

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

def f(z):
    return z ** 2 -2 * z + 1

def df(z):
    return 2 * z - 2

def newton_set2(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1 # max error allowed

    # Bounding roots
    r1 = 1

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display2(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set2(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(x)=Z^2-2z+1')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=x^2-2x+1')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# #$x^{2}-1$

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

def f(z):
    return z ** 2 - 1

def df(z):
    return 2 * z

def newton_set3(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = 1
    r2 = -1

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display3(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set3(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(x)=Z^2-1')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=x^2-1')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# #$x^{2}+1$

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

def f(z):
    return z ** 2 + 1

def df(z):
    return 2 * z

def newton_set4(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = complex(0,1)
    r2 = complex(0,-1)

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display4(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set4(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(x)=Z^2+1')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=x^2+1')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# #2. Apply the Classic and Po Shen Loh ‘s methods for solving the following quadratic equations

# %%
import cmath

# %% [markdown]
# #Metodo de la formula cuadratica

# %%
def cuadratic(a,b,c):
  raices = []
  num_sqrt= b**2 - (4*a*c)
  #raiz 1
  if (num_sqrt>=0):
    numerador = -1*b + math.sqrt(num_sqrt)
    denominador = 2*a
    raiz1 = (numerador/denominador)
    raices.append(raiz1)
  else:
    numerador = -1*b + cmath.sqrt(num_sqrt)
    denominador = 2*a
    raiz1 = (numerador/denominador)
    raices.append(raiz1)
  
  #raiz2
  if (num_sqrt>=0):
    numerador = -1*b - math.sqrt(num_sqrt)
    denominador = 2*a
    raiz2 = (numerador/denominador)
    raices.append(raiz2)
  else:
    numerador = -1*b - cmath.sqrt(num_sqrt)
    denominador = 2*a
    raiz2 = (numerador/denominador)
    raices.append(raiz2)
  
  if (raices[0]==raices[1]):
    raices.pop()
    return raices
  else:
    return raices

# %% [markdown]
# #Metodo de  Po Shen Loh ‘s

# %%
def po_shen_loh(b,c):
  raices=[]
  if (b!=0):
    denominador = 4
  else:
    denominador = 1
  num_sqrt = b**2 - (c* denominador)

  numerador = -1*b
  #raiz 1
  if (num_sqrt>=0):
    raiz1 = (numerador/2)+math.sqrt(num_sqrt)

    raices.append(raiz1)
  else:
    raiz1 = (numerador/2)+cmath.sqrt(num_sqrt)
    raices.append(raiz1)

  #raiz 2
  if (num_sqrt>=0):
    raiz2 = (numerador/2)-math.sqrt(num_sqrt)
    raices.append(raiz2)
  else:
    raiz2 = (numerador/2)-cmath.sqrt(num_sqrt)
    raices.append(raiz2)

  if (raices[0]==raices[1]):
    raices.pop()
    return raices
  else:
    return raices

# %% [markdown]
# #$x^{2}$

# %%
print('Con la formula cuadratica las raices son: ', cuadratic(1,0,0))
print('Con el metodo de Po shen lo´h las raices son: ', po_shen_loh(0,0))
# Out:
# Con la formula cuadratica las raices son:  [0.0]
# Con el metodo de Po shen lo´h las raices son:  [0.0]

# %% [markdown]
# #$(x-1)^{2} = x^{2}-2x+1$

# %%
print('Con la formula cuadratica las raices son: ', cuadratic(1,-2,1))
print('Con el metodo de Po shen lo´h las raices son: ', po_shen_loh(-2,1))
# Out:
# Con la formula cuadratica las raices son:  [1.0]
# Con el metodo de Po shen lo´h las raices son:  [1.0]

# %% [markdown]
# #$x^{2}-1$

# %%
print('Con la formula cuadratica las raices son: ', cuadratic(1,0,-1))
print('Con el metodo de Po shen lo´h las raices son: ', po_shen_loh(0,-1))
# Out:
# Con la formula cuadratica las raices son:  [1.0, -1.0]
# Con el metodo de Po shen lo´h las raices son:  [1.0, -1.0]

# %% [markdown]
# #$x^{2}+1$

# %%
print('Con la formula cuadratica las raices son: ', cuadratic(1,0,1))
print('Con el metodo de Po shen lo´h las raices son: ', po_shen_loh(0,1))
# Out:
# Con la formula cuadratica las raices son:  [1j, -1j]
# Con el metodo de Po shen lo´h las raices son:  [1j, -1j]

# %% [markdown]
# #3. to plot the newton fractals for the corresponding complex quadratic polynomials

# %% [markdown]
# #$x^{2}$

# %%
print("zoom out")
display1(zoom=1)
display1(zoom=2)
display1(zoom=3)
display1(zoom=4)
display1(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %%
print("zoom in")
display1(zoom=1)
display1(zoom=1/2)
display1(zoom=1/3)
display1(zoom=1/4)
display1(zoom=1/5)
display1(zoom=1/10)
display1(zoom=1/100)
display1(zoom=1/1000)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# ##Revisando este fractal es entendible que aparezca ese punto en el centro de la imagen esto quiere decir que dicho punto es la raiz 0 de la funcion $x^{2}$

# %% [markdown]
# #$(x-1)^{2} = x^{2}-2x+1$

# %%
print("zoom out")
display2(zoom=1)
display2(zoom=2)
display2(zoom=3)
display2(zoom=4)
display2(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %%
print("zoom in")
display2(zoom=1)
display2(zoom=1/2)
display2(zoom=1/3)
display2(zoom=1/4)
display2(zoom=1/5)
display2(zoom=1/10)
display2(zoom=1/100)
display2(zoom=1/1000)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# ##Para este fractal fue necesario bajar el margen de error permitido (la variable eps) esta variable eps originalmente tenia un valor de 1e-3 y fue cambiada al valor de 1 para que el fractal se pudiera graficar, para esta funcion $(x-1)^{2} = x^{2}-2x+1$ el punto rojo aparece a la derecha, esto tiene sentido ya que la raiz de la funcion es 1 y este valor esta en la parte positiva(derecha) de las coordenadas.

# %% [markdown]
# #$x^{2}-1$

# %%
print("zoom out")
display3(zoom=1)
display3(zoom=2)
display3(zoom=3)
display3(zoom=4)
display3(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %%
print("zoom in")
display3(zoom=1)
display3(zoom=1/2)
display3(zoom=1/3)
display3(zoom=1/4)
display3(zoom=1/5)
display3(zoom=1/10)
display3(zoom=1/100)
display3(zoom=1/1000)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# ##Para En este fractal se ve reflejado en el color verde la raiz de -1 y en el color rojo la raiz 1, de la funcion $x^{2}-1$

# %% [markdown]
# #$x^{2}+1$

# %%
print("zoom out")
display4(zoom=1)
display4(zoom=2)
display4(zoom=3)
display4(zoom=4)
display4(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %%
print("zoom in")
display4(zoom=1)
display4(zoom=1/2)
display4(zoom=1/3)
display4(zoom=1/4)
display4(zoom=1/5)
display4(zoom=1/10)
display4(zoom=1/100)
display4(zoom=1/1000)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# ##Para la función de $x^{2}+1$ sus raices son i y -i por lo tanto a diferencia de la función $x^{2}-1$ el fractal cambia de eje y esto es debido a que cuando graficamos un numero complejo en un plano, el eje Y pasa a ser el eje del componente complejo, el eje X seria el componente real.

# %% [markdown]
# #4. Plot the Newton iterates for points on the positive and negative axes for the complex quadratic polynomials in 3. Give an interpretation of the results.

# %% [markdown]
# #$x^{2}$

# %% [markdown]
# ## Newton iterates form z=10.0 + 0.0j

# %%
def f(z):
    return z ** 2

def df(z):
    return 2 * z

z=10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# ##La funcion $x^{2}$ para un z=10.0 + 0.0j en su componente real converge en el valor de 0, y en su componente compleja se mantiene en 0

# %% [markdown]
# ## Newton iterates form z=-10.0 + 0.0j

# %%
def f(z):
    return z ** 2

def df(z):
    return 2 * z

z=-10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ##La funcion $x^{2}$ para un z=-10.0 + 0.0j en su componente real converge en el valor de 0, y en su componente compleja se mantiene en 0

# %% [markdown]
# ## Newton iterates form z=0.0 + 10.0j

# %%
def f(z):
    return z ** 2

def df(z):
    return 2 * z

z=-0.0 + 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ##La funcion $x^{2}$ para un z=-10.0 + 0.0j en su componente real se mantiene en el valor de 0, y en su componente compleja tambien converge en 0

# %% [markdown]
# ## Newton iterates form z=0.0 - 10.0j

# %%
def f(z):
    return z ** 2

def df(z):
    return 2 * z

z=-0.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ##La funcion $x^{2}$ para un z=-0.0 - 10.0j en su componente real se mantiene en el valor de 0, y en su componente compleja tambien converge en 0

# %% [markdown]
# ## Newton iterates form z=0.0 + 0.0j

# %%
def f(z):
    return z ** 2

def df(z):
    return 2 * z

z=-0.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-83-6be37f7edef3> in <module>()
#      10 for k in range(200):
#      11   dz = df(z)
# ---> 12   z = z - f(z) / dz # Newton iteration
#      13   r.append(np.real(z))
#      14   i.append(np.imag(z))
#
# ZeroDivisionError: complex division by zero

# %% [markdown]
# ##La funcion $x^{2}$ para un z=-0.0 + 0.0j diverge

# %% [markdown]
# #$(x-1)^{2} = x^{2}-2x+1$

# %% [markdown]
# ## Newton iterates form z=10.0 + 0.0j

# %%
def f(z):
    return z**2 - 2*z + 1

def df(z):
    return 2 * z -2

z=10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# La función $(x-1)^{2} = x^{2}-2x+1$ y para un z=10.0 + 0.0j  en su componente real converge al valor de 1 y en su componente compleja se mantiene en cero

# %% [markdown]
# ## Newton iterates form z=-10.0 + 0.0j

# %%
def f(z):
    return z**2 - 2*z + 1

def df(z):
    return 2 * z -2

z=-10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# La función $(x-1)^{2} = x^{2}-2x+1$ y para un z=-10.0 + 0.0j  en su componente real converge al valor de 1 y en su componente compleja se mantiene en cero

# %% [markdown]
# ## Newton iterates form z=0.0 + 10.0j

# %%
def f(z):
    return z**2 - 2*z + 1

def df(z):
    return 2 * z -2

z=-0.0 + 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# La función $(x-1)^{2} = x^{2}-2x+1$ y para un z=-0.0 + 10.0j  en su componente real converge al valor de 1 y en su componente compleja converge en cero

# %% [markdown]
# ## Newton iterates form z=0.0 - 10.0j

# %%
def f(z):
    return z**2 - 2*z + 1

def df(z):
    return 2*z-2

z=-0.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# La función $(x-1)^{2} = x^{2}-2x+1$ y para un z=-0.0 - 10.0j  en su componente real converge al valor de 1 y en su componente compleja converge en cero

# %% [markdown]
# ## Newton iterates form z=0.0 + 0.0j

# %%
def f(z):
    return z**2 - 2*z + 1

def df(z):
    return 2 * z -2

z=-0.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# La función $(x-1)^{2} = x^{2}-2x+1$ y para un z=-0.0 + 0.0j  en su componente real converge al valor de 1 y en su componente compleja se mantiene en cero

# %% [markdown]
# #$x^{2}-1$

# %% [markdown]
# ## Newton iterates form z=10.0 + 0.0j

# %%
def f(z):
    return z**2 -  1

def df(z):
    return 2 * z 

z=10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# La función $x^{2}-1$ para un z=10.0 + 0.0j en su componente real converge en el valor de 1 y en su componente complejo se mantiene en cero

# %% [markdown]
# ## Newton iterates form z=-10.0 + 0.0j

# %%
def f(z):
    return z**2 -  1

def df(z):
    return 2 * z 

z=-10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# La función $x^{2}-1$ para un z=-10.0 + 0.0j en su componente real converge en el valor de 1 y en su componente complejo se mantiene en cero

# %% [markdown]
# ## Newton iterates form z=0.0 + 10.0j

# %%
def f(z):
    return z**2 -  1

def df(z):
    return 2 * z 

z=0.0 + 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# La función $x^{2}-1$ para un z=0.0 + 10.0j en su componente real se mantiene en cero y en su componente complejo diverge

# %% [markdown]
# ## Newton iterates form z=0.0 - 10.0j

# %%
def f(z):
    return z**2 -  1

def df(z):
    return 2 * z 

z=0.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# La función $x^{2}-1$ para un z=0.0 - 10.0j en su componente real se mantiene en cero y en su componente complejo diverge

# %% [markdown]
# ## Newton iterates form z=0.0 + 0.0j

# %%
def f(z):
    return z**2 -  1

def df(z):
    return 2 * z 

z=0.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-93-2df48340a934> in <module>()
#      10 for k in range(200):
#      11   dz = df(z)
# ---> 12   z = z - f(z) / dz # Newton iteration
#      13   r.append(np.real(z))
#      14   i.append(np.imag(z))
#
# ZeroDivisionError: complex division by zero

# %% [markdown]
# La función $x^{2}-1$ para un z=0.0 + 0.0j diverge

# %% [markdown]
# #$x^{2}+1$

# %% [markdown]
# ## Newton iterates form z=10.0 + 0.0j

# %%
def f(z):
    return z**2 + 1

def df(z):
    return 2 * z

z=10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# La función $x^{2}+1$ en un z=10.0 + 0.0j en su componente real diverge y en su componente complejo se mantiene en cero

# %% [markdown]
# ## Newton iterates form z=-10.0 + 0.0j

# %%
def f(z):
    return z**2 + 1

def df(z):
    return 2 * z

z=-10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# La función $x^{2}+1$ en un z=-10.0 + 0.0j en su componente real diverge y en su componente complejo se mantiene en cero

# %% [markdown]
# ## Newton iterates form z=0.0 + 10.0j

# %%
def f(z):
    return z**2 + 1

def df(z):
    return 2 * z

z=-0.0 + 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# La función $x^{2}+1$ en un z=-0.0 + 10.0j en su componente real se mantiene en cero  y en su componente complejo converge en 1

# %% [markdown]
# ## Newton iterates form z=0.0 - 10.0j

# %%
def f(z):
    return z**2 + 1

def df(z):
    return 2*z

z=-0.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# La función $x^{2}+1$ en un z=-0.0 - 10.0j en su componente real se mantiene en cero  y en su componente complejo converge en 1

# %% [markdown]
# ## Newton iterates form z=0.0 + 0.0j

# %%
def f(z):
    return z**2 + 1

def df(z):
    return 2 * z

z=-0.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-98-d64d4d2a6e60> in <module>()
#      10 for k in range(200):
#      11   dz = df(z)
# ---> 12   z = z - f(z) / dz # Newton iteration
#      13   r.append(np.real(z))
#      14   i.append(np.imag(z))
#
# ZeroDivisionError: complex division by zero

# %% [markdown]
# La función $x^{2}+1$ en un z=-0.0 + 0.0j diverge

# %% [markdown]
# #5. Plot he Newton iterates for points on the diagonals in the four quadrants and 0.0 + 0.0j for the complex quadratic polynomials in 3. Give an interpretation of the results.
#
# #6. Describe in one after cell after each quadratic function the regions where starting points x0 converge and to which root does it converge. Also which regions do not converge and why.

# %% [markdown]
# #$z^2$

# %% [markdown]
# ## Newton iterates form z=10.0 + 10.0j

# %%
def f(z):
    return z ** 2

def df(z):
    return 2 * z

z=10.0 + 10.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# La función $z^2$ con un z=10.0 + 10.0j converge en cero para sus componentes real y compleja.

# %% [markdown]
# ## Newton iterates form z=-10.0 + 10.0j

# %%
def f(z):
    return z ** 2

def df(z):
    return 2 * z

z=-10.0 + 10.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
#  La función $z^2$ con un z=-10.0 + 10.0j converge en cero para sus componentes real y compleja.

# %% [markdown]
# ## Newton iterates form z=-10.0 - 10.0j

# %%
def f(z):
    return z ** 2

def df(z):
    return 2 * z

z=-10.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
#  La función $z^2$ con un z=-10.0 - 10.0j converge en cero para sus componentes real y compleja.

# %% [markdown]
# ## Newton iterates form z=10.0 - 10.0j

# %%
def f(z):
    return z ** 2

def df(z):
    return 2 * z

z=10.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
#  La función $z^2$ con un z=10.0 - 10.0j converge en cero para sus componentes real y compleja.

# %% [markdown]
# #$(x-1)^{2} = x^{2}-2x+1$

# %% [markdown]
# ## Newton iterates form z=10.0 + 10.0j

# %%
def f(z):
    return z**2 - 2*z + 1

def df(z):
    return 2 * z -2

z=10.0 + 10.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# La función $(x-1)^{2} = x^{2}-2x+1$ en un z=10.0 + 10.0j en su componente real converge en 1 y en su componente compleja converge en 0

# %% [markdown]
# ## Newton iterates form z=-10.0 + 10.0j

# %%
def f(z):
    return z**2 - 2*z + 1

def df(z):
    return 2 * z -2

z=-10.0 + 10.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# La función $(x-1)^{2} = x^{2}-2x+1$ en un z=-10.0 + 10.0j en su componente real converge en 1 y en su componente compleja converge en 0

# %% [markdown]
# ## Newton iterates form z=-10.0 - 10.0j

# %%
def f(z):
    return z**2 - 2*z + 1

def df(z):
    return 2 * z -2

z=-10.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# La función $(x-1)^{2} = x^{2}-2x+1$ en un z=-10.0 - 10.0j en su componente real converge en 1 y en su componente compleja converge en 0

# %% [markdown]
# ## Newton iterates form z=10.0 - 10.0j

# %%
def f(z):
    return z**2 - 2*z + 1

def df(z):
    return 2 * z -2

z=10.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# La función $(x-1)^{2} = x^{2}-2x+1$ en un z=10.0 - 10.0j en su componente real converge en 1 y en su componente compleja converge en 0

# %% [markdown]
# # $x^2-1$

# %% [markdown]
# ## Newton iterates form z=10.0 + 10.0j

# %%
def f(z):
    return z**2 - 1

def df(z):
    return 2 * z

z=10.0 + 10.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# La función $x^2-1$  con un z=10.0 + 10.0j para su componente real converge en 1 y para su componente compleja converge en cero

# %% [markdown]
# ## Newton iterates form z=-10.0 + 10.0j

# %%
def f(z):
    return z ** 2 -1

def df(z):
    return 2 * z

z=-10.0 + 10.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# La función $x^2-1$  con un z=-10.0 + 10.0j para su componente real converge en -1 y para su componente compleja converge en cero

# %% [markdown]
# ## Newton iterates form z=-10.0 - 10.0j

# %%
def f(z):
    return z ** 2 -1

def df(z):
    return 2 * z

z=-10.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# La función $x^2-1$  con un z=-10.0 - 10.0j para su componente real converge en -1 y para su componente compleja converge en cero

# %% [markdown]
# ## Newton iterates form z=10.0 - 10.0j

# %%
def f(z):
    return z ** 2 -1

def df(z):
    return 2 * z

z=10.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# La función $x^2-1$  con un z=10.0 - 10.0j para su componente real converge en 1 y para su componente compleja converge en cero

# %% [markdown]
# # $x^2 +1$

# %% [markdown]
# ## Newton iterates form z=10.0 + 10.0j

# %%
def f(z):
    return z**2 + 1

def df(z):
    return 2 * z

z=10.0 + 10.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Para una función $x^2 +1$ con un z=10.0 + 10.0j en su componente real converge en cero y en su componente compleja converge en 1

# %% [markdown]
# ## Newton iterates form z=-10.0 + 10.0j

# %%
def f(z):
    return z ** 2 +1

def df(z):
    return 2 * z

z=-10.0 + 10.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# Para una función $x^2 +1$ con un z=-10.0 + 10.0j en su componente real converge en cero y en su componente compleja converge en 1

# %% [markdown]
# ## Newton iterates form z=-10.0 - 10.0j

# %%
def f(z):
    return z ** 2 +1

def df(z):
    return 2 * z

z=-10.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# Para una función $x^2 +1$ con un z=-10.0 - 10.0j en su componente real converge en cero y en su componente compleja converge en -1

# %% [markdown]
# ## Newton iterates form z=10.0 - 10.0j

# %%
def f(z):
    return z ** 2 +1

def df(z):
    return 2 * z

z=10.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# Para una función $x^2 +1$ con un z=10.0 - 10.0j en su componente real converge en cero y en su componente compleja converge en -1
